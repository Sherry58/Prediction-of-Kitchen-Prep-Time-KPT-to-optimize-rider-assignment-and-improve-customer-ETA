# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("/Users/sherry/Desktop/HACKATHON/zomato_kpt__Final_Dataset2.csv")

# %%
sns.histplot(df["prep_time"], bins=50, kde=True)
plt.title("Prep Time Distribution")
plt.show()

# %%
df.shape
# Out:
# (550502, 17)

# %%
df.sample(10)
# Out:
#                  order_time  restaurant_id  cuisine_type  restaurant_capacity  \
# 415817  2024-01-23 19:25:00              5  North Indian                    4
# 40662   2024-01-03 12:15:00            137  North Indian                    6
# 274876  2024-01-15 22:50:00            119       Chinese                    5
# 198397  2024-01-11 23:40:00             12          Cafe                    8
# 124595  2024-01-07 20:25:00            119       Chinese                    5
# 157007  2024-01-09 16:45:00             77  South Indian                   12
# 177728  2024-01-10 20:45:00            167         Pizza                    9
# 304342  2024-01-17 19:35:00             17      Desserts                   15
# 175809  2024-01-10 19:20:00            159  North Indian                   16
# 382367  2024-01-21 20:45:00             82          Cafe                   14
#
#         restaurant_rating  chef_count  efficiency_score  total_items  \
# ...

# %%
df.describe()
# Out:
#        restaurant_id  restaurant_capacity  restaurant_rating     chef_count  \
# count  550502.000000        550502.000000      550502.000000  550502.000000
# mean      100.682426            10.882722           4.270943       5.995388
# std        56.128945             4.249872           0.558938       2.113678
# min         0.000000             4.000000           3.000000       3.000000
# 25%        52.000000             7.000000           3.800000       4.000000
# 50%        97.000000            11.000000           4.400000       6.000000
# 75%       149.000000            14.000000           4.700000       8.000000
# max       199.000000            19.000000           5.000000       9.000000
#
#        efficiency_score    total_items  item_complexity_score  \
# count     550502.000000  550502.000000          550502.000000
# mean           1.007651       3.500214               6.129504
# std            0.119339       1.706080               3.435258
# ...

# %%
sns.countplot(x="cuisine_type", data=df)
plt.xticks(rotation=60)
plt.show()

# %%
corr = df.corr(numeric_only=True)
corr
# Out:
#                           restaurant_id  restaurant_capacity  \
# restaurant_id                  1.000000             0.091383
# restaurant_capacity            0.091383             1.000000
# restaurant_rating              0.046681             0.033899
# chef_count                     0.085994             0.963458
# efficiency_score               0.020619             0.024385
# total_items                   -0.000823            -0.001006
# item_complexity_score          0.000105            -0.002097
# active_orders_in_kitchen      -0.033662            -0.105734
# queue_length                  -0.075040            -0.253757
# kitchen_utilization           -0.081065            -0.367624
# festival_flag                 -0.001755            -0.002844
# hour                           0.000249             0.000439
# weekend                        0.000964             0.001189
# prep_time                     -0.053728            -0.212410
#
# ...

# %%
sns.heatmap(corr, cmap="coolwarm")
plt.title("Correlation Matrix")
plt.show()

# %%
corr["prep_time"].sort_values(ascending=False)
# Out:
# prep_time                   1.000000
# kitchen_utilization         0.593940
# queue_length                0.550658
# active_orders_in_kitchen    0.523272
# item_complexity_score       0.449038
# total_items                 0.391786
# hour                        0.117497
# weekend                     0.047647
# restaurant_rating           0.010707
# festival_flag               0.002655
# efficiency_score           -0.012249
# restaurant_id              -0.053728
# chef_count                 -0.194960
# restaurant_capacity        -0.212410
# Name: prep_time, dtype: float64

# %%
sns.pairplot(df)
plt.show()

# %%
df.hist(bins=30, figsize=(20,15))
plt.show()

# %%
from ydata_profiling import ProfileReport

profile = ProfileReport(df)

profile.to_file("eda_report3.html")
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
